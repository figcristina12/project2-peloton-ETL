# %%
import pandas as pd
from pathlib import Path

# %%
peloton_instructors=Path ('instructors.csv')

# %%
peloton_instructors_df= pd.read_csv(peloton_instructors)
peloton_instructors_df.head (200)
# Out:
#                                   id  \
# 0   b8c2734e18a7496fa146b3a42465da67
# 1   f962a2b1b34d424cabab73bef81bc8db
# 2   15f01c9145de4d21b58c1a3e4e44a486
# 3   2e57092bee334c8c8dcb9fe16ba5308c
# 4   731d7b7f6b414a49892c21f01e25317d
# 5   c9fa21c2004c4544a7c35c28a6196c77
# 6   a8c56f162c964e9392568bc13828a3fb
# 7   1f4d39cd181c4805a00cd0a53f6c9562
# 8   16f7a0fa5ee64e1f8fc050c8a903ac9b
# 9   286fc17080d34406a54b80ad8ff83e12
# 10  7f3de5e78bb44d8591a0f77f760478c3
# 11  accfd3433b064508845d7696dab959fd
# 12  01f636dc54a145239c4348e1736684ee
# 13  255c81782f7242c9a6ba52e0a5f54912
# 14  696bd08dd5284accab065e2147b121d7
# 15  0ac29effd55a435bad2f5c07cab8e567
# 16  0021e2220a7940cf94a7647b1e4bae6c
# 17  5a19bfe66e644a2fa3e6387a91ebc5ce
# 18  e2e6586d898d4422b3f6e3a259ff3f90
# 19  baf5dfb4c6ac4968b2cb7f8f8cc0ef10
# 20  1e59e949a19341539214a4a13ea7ff01
# 21  f6f2d613dc344e4bbf6428cd34697820
# 22  017dd08b095346979ddf761eb49f9f67
# 23  561f95c405734d8488ed8dcc8980d599
# ...

# %%
peloton_instructors_df.describe()
# Out:
#        list_order  film_link  instagram_profile  strava_profile  \
# count   58.000000        0.0                0.0             0.0
# mean    39.517241        NaN                NaN             NaN
# std     17.038904        NaN                NaN             NaN
# min     10.000000        NaN                NaN             NaN
# 25%     25.250000        NaN                NaN             NaN
# 50%     39.500000        NaN                NaN             NaN
# 75%     53.750000        NaN                NaN             NaN
# max     71.000000        NaN                NaN             NaN
#
#        twitter_profile  bike_instructor_list_display_image_url  \
# count              0.0                                     0.0
# mean               NaN                                     NaN
# std                NaN                                     NaN
# min                NaN                                     NaN
# 25%                NaN                                     NaN
# ...

# %%
peloton_instructors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 38 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   id                                      58 non-null     object
#  1   bio                                     58 non-null     object
#  2   short_bio                               50 non-null     object
#  3   coach_type                              58 non-null     object
#  4   is_filterable                           58 non-null     bool
#  5   is_instructor_group                     58 non-null     bool
#  6   is_visible                              58 non-null     bool
#  7   is_announced                            58 non-null     bool
#  8   list_order                              58 non-null     int64
#  9   featured_profile                        58 non-null     bool
# ...

# %%
peloton_instructors_df.drop (columns=['bio', 'short_bio', 'coach_type', 'is_filterable',
'is_instructor_group',
'is_visible',
'is_announced',
'list_order',
'featured_profile',
'film_link',
'facebook_fan_page',
'music_bio',
'spotify_playlist_uri',
'background',
'ordered_q_and_as',
'instagram_profile',
'strava_profile',
'twitter_profile',
'username',
'first_name',
'last_name',
'user_id',
'life_style_image_url',
'bike_instructor_list_display_image_url',
'web_instructor_list_display_image_url',
'ios_instructor_list_display_image_url',
'about_image_url',
'image_url',
'jumbotron_url',
'jumbotron_url_dark',
'jumbotron_url_ios',
'web_instructor_list_gif_image_url',
'instructor_hero_image_url',
'workout_share_images',
'fitness_disciplines'], inplace=True)

# %%
peloton_instructors_df.head (200)
# Out:
#                                   id  \
# 0   b8c2734e18a7496fa146b3a42465da67
# 1   f962a2b1b34d424cabab73bef81bc8db
# 2   15f01c9145de4d21b58c1a3e4e44a486
# 3   2e57092bee334c8c8dcb9fe16ba5308c
# 4   731d7b7f6b414a49892c21f01e25317d
# 5   c9fa21c2004c4544a7c35c28a6196c77
# 6   a8c56f162c964e9392568bc13828a3fb
# 7   1f4d39cd181c4805a00cd0a53f6c9562
# 8   16f7a0fa5ee64e1f8fc050c8a903ac9b
# 9   286fc17080d34406a54b80ad8ff83e12
# 10  7f3de5e78bb44d8591a0f77f760478c3
# 11  accfd3433b064508845d7696dab959fd
# 12  01f636dc54a145239c4348e1736684ee
# 13  255c81782f7242c9a6ba52e0a5f54912
# 14  696bd08dd5284accab065e2147b121d7
# 15  0ac29effd55a435bad2f5c07cab8e567
# 16  0021e2220a7940cf94a7647b1e4bae6c
# 17  5a19bfe66e644a2fa3e6387a91ebc5ce
# 18  e2e6586d898d4422b3f6e3a259ff3f90
# 19  baf5dfb4c6ac4968b2cb7f8f8cc0ef10
# 20  1e59e949a19341539214a4a13ea7ff01
# 21  f6f2d613dc344e4bbf6428cd34697820
# 22  017dd08b095346979ddf761eb49f9f67
# 23  561f95c405734d8488ed8dcc8980d599
# ...

# %%
peloton_instructors_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      58 non-null     object
#  1   quote   57 non-null     object
#  2   name    58 non-null     object
# dtypes: object(3)
# memory usage: 1.5+ KB

# %%
def encode_decode_text(text):
    if isinstance(text, str):

        return text.encode('latin-1', errors='ignore').decode('utf-8', errors='ignore')
    else:
        return text


peloton_instructors_df['quote'] = peloton_instructors_df['quote'].apply(encode_decode_text)

# %%
def encode_decode_text(text):
    if isinstance(text, str):

        return text.encode('latin-1', errors='ignore').decode('utf-8', errors='ignore')
    else:
        return text


peloton_instructors_df['name'] = peloton_instructors_df['name'].apply(encode_decode_text)

peloton_instructors_df.head (200)
# Out:
#                                   id  \
# 0   b8c2734e18a7496fa146b3a42465da67
# 1   f962a2b1b34d424cabab73bef81bc8db
# 2   15f01c9145de4d21b58c1a3e4e44a486
# 3   2e57092bee334c8c8dcb9fe16ba5308c
# 4   731d7b7f6b414a49892c21f01e25317d
# 5   c9fa21c2004c4544a7c35c28a6196c77
# 6   a8c56f162c964e9392568bc13828a3fb
# 7   1f4d39cd181c4805a00cd0a53f6c9562
# 8   16f7a0fa5ee64e1f8fc050c8a903ac9b
# 9   286fc17080d34406a54b80ad8ff83e12
# 10  7f3de5e78bb44d8591a0f77f760478c3
# 11  accfd3433b064508845d7696dab959fd
# 12  01f636dc54a145239c4348e1736684ee
# 13  255c81782f7242c9a6ba52e0a5f54912
# 14  696bd08dd5284accab065e2147b121d7
# 15  0ac29effd55a435bad2f5c07cab8e567
# 16  0021e2220a7940cf94a7647b1e4bae6c
# 17  5a19bfe66e644a2fa3e6387a91ebc5ce
# 18  e2e6586d898d4422b3f6e3a259ff3f90
# 19  baf5dfb4c6ac4968b2cb7f8f8cc0ef10
# 20  1e59e949a19341539214a4a13ea7ff01
# 21  f6f2d613dc344e4bbf6428cd34697820
# 22  017dd08b095346979ddf761eb49f9f67
# 23  561f95c405734d8488ed8dcc8980d599
# ...

# %%
peloton_instructors_df.rename(columns={'quote': 'Favorite Quote'}, inplace=True)

peloton_instructors_df.rename(columns={'name': 'Instructor Name'}, inplace=True)

# %%
peloton_instructors_df.head (200)
# Out:
#                                   id  \
# 0   b8c2734e18a7496fa146b3a42465da67
# 1   f962a2b1b34d424cabab73bef81bc8db
# 2   15f01c9145de4d21b58c1a3e4e44a486
# 3   2e57092bee334c8c8dcb9fe16ba5308c
# 4   731d7b7f6b414a49892c21f01e25317d
# 5   c9fa21c2004c4544a7c35c28a6196c77
# 6   a8c56f162c964e9392568bc13828a3fb
# 7   1f4d39cd181c4805a00cd0a53f6c9562
# 8   16f7a0fa5ee64e1f8fc050c8a903ac9b
# 9   286fc17080d34406a54b80ad8ff83e12
# 10  7f3de5e78bb44d8591a0f77f760478c3
# 11  accfd3433b064508845d7696dab959fd
# 12  01f636dc54a145239c4348e1736684ee
# 13  255c81782f7242c9a6ba52e0a5f54912
# 14  696bd08dd5284accab065e2147b121d7
# 15  0ac29effd55a435bad2f5c07cab8e567
# 16  0021e2220a7940cf94a7647b1e4bae6c
# 17  5a19bfe66e644a2fa3e6387a91ebc5ce
# 18  e2e6586d898d4422b3f6e3a259ff3f90
# 19  baf5dfb4c6ac4968b2cb7f8f8cc0ef10
# 20  1e59e949a19341539214a4a13ea7ff01
# 21  f6f2d613dc344e4bbf6428cd34697820
# 22  017dd08b095346979ddf761eb49f9f67
# 23  561f95c405734d8488ed8dcc8980d599
# ...

# %%
import pandas as pd
from pathlib import Path

# %%
peloton_workouts=Path ('workouts.csv')

# %%
peloton_workouts_df= pd.read_csv(peloton_workouts,low_memory=False)

#removed rows with all NaN values
peloton_workouts_df= peloton_workouts_df.dropna(how='all')

peloton_workouts_df.head (40000)
# Out:
#                                      id  \
# 2      9631041632fd488b80f5a8aacd69fb7d
# 5      c4f2dc9a6b714250b29172afa3dec69e
# 6      a88afd308f2345a78776f2ad7f14cd23
# 11     53b12f2299bd4689a14e0ad77f951729
# 12     ef1f5cee1b634bf8950e668864f7ee89
# ...                                 ...
# 32520  b011b2d9d8804827948780c3838efb69
# 32522  7a4edb2d43874ad4af61e553be290ccc
# 32523  68e5caee144b49da927422b65d1c10ad
# 32526  06846764cd874a12b3885ad8473b662e
# 32527  02ef1fda9edd4090a8500f026e919122
#
#                                  availability  \
# 2      {'is_available': True, 'reason': None}
# 5      {'is_available': True, 'reason': None}
# 6      {'is_available': True, 'reason': None}
# 11     {'is_available': True, 'reason': None}
# 12     {'is_available': True, 'reason': None}
# ...                                       ...
# 32520  {'is_available': True, 'reason': None}
# 32522  {'is_available': True, 'reason': None}
# 32523  {'is_available': True, 'reason': None}
# ...

# %%
peloton_workouts_df.describe()
# Out:
#        difficulty_estimate  overall_estimate  difficulty_rating_avg  \
# count          9502.000000       9502.000000            9502.000000
# mean              6.381986          0.988510               6.381986
# std               1.200051          0.018994               1.200051
# min               0.000000          0.000000               0.000000
# 25%               5.475175          0.986700               5.475175
# 50%               6.589550          0.992400               6.589550
# 75%               7.275175          0.995300               7.275175
# max              10.000000          1.000000              10.000000
#
#        difficulty_rating_count     duration  explicit_rating       length  \
# count              9502.000000  9502.000000      9502.000000  9502.000000
# mean               6372.845506  1538.234056         0.371711  1716.605872
# std                8167.935482   731.103352         0.483287   743.746654
# ...

# %%
peloton_workouts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9502 entries, 2 to 32527
# Data columns (total 73 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   9502 non-null   object
#  1   availability                         9502 non-null   object
#  2   class_type_ids                       9502 non-null   object
#  3   content_provider                     9502 non-null   object
#  4   content_format                       9502 non-null   object
#  5   description                          9502 non-null   object
#  6   difficulty_estimate                  9502 non-null   float64
#  7   overall_estimate                     9502 non-null   float64
#  8   difficulty_rating_avg                9502 non-null   float64
#  9   difficulty_rating_count              9502 non-null   float64
#  10  difficulty_level                     9502 non-null   object
# ...

# %%
peloton_workouts_df.drop(columns=['id','availability',
'class_type_ids',
'content_provider',
'content_format',
'difficulty_estimate',
'overall_estimate',
'difficulty_rating_avg',
'difficulty_rating_count',
'duration',
'equipment_ids',
'equipment_tags',
'explicit_rating',
'extra_images',
'fitness_discipline_display_name',
'has_closed_captions',
'has_pedaling_metrics',
'home_peloton_id',
'image_url',
'individual_instructor_ids',
'is_archived',
'is_closed_caption_shown', 
'has_free_mode',
'is_live_in_studio_only',
'language',
'origin_locale',
'length',
'live_stream_id', 
'live_stream_url',
'location',
'original_air_time',
'overall_rating_avg',
'overall_rating_count',
'pedaling_start_offset',
'pedaling_end_offset',
'pedaling_duration',
'rating', 
'ride_type_id',  
'ride_type_ids',
'sample_vod_stream_url',
'sample_preview_stream_url',
'scheduled_start_time',
'series_id', 
'sold_out',
'studio_peloton_id',
'total_ratings',
'total_in_progress_workouts',
'total_workouts', 
'vod_stream_url',
'vod_stream_id',
'captions',
'join_tokens',
'flags',
'is_dynamic_video_eligible',
'is_fixed_distance',
'dynamic_video_recorded_speed_in_mph',
'thumbnail_title', 
'thumbnail_location',
'distance',
'distance_unit',
'distance_display_value',
'muscle_group_score',
'is_sessions_eligible',
'total_user_workouts',
'total_following_workouts',
'is_favorite'], inplace=True)

# %%
def encode_decode_text(text):
    if isinstance(text, str):

        return text.encode('latin-1', errors='ignore').decode('utf-8', errors='ignore')
    else:
        return text


peloton_workouts_df['description'] = peloton_workouts_df['description'].apply(encode_decode_text)

# %%
peloton_workouts_df[['duration', 'workout_type']] = peloton_workouts_df['title'].str.extract(r'(\d+\s*min)\s*(.*)')
peloton_workouts_df['duration'] = peloton_workouts_df['duration'].str.strip()
peloton_workouts_df['workout_type'] = peloton_workouts_df['workout_type'].str.strip()


print(peloton_workouts_df[['duration', 'workout_type']])
# Out:
#       duration                workout_type
# 2       20 min  Seated Adaptive Upper Body
# 5       30 min                  Power Flow
# 6       20 min         Upper Body Strength
# 11      30 min               Intervals Run
# 12      20 min           Morning Yoga Flow
# ...        ...                         ...
# 32520   30 min   Yoga Flow: Live from Home
# 32522   20 min      Glutes & Legs Strength
# 32523   45 min                   Hills Run
# 32526   20 min   Arms & Shoulders Strength
# 32527   10 min                   Yoga Flow
#
# [9502 rows x 2 columns]

# %%
peloton_workouts_df.drop(columns=['title'
], inplace=True)

# %%
peloton_workouts_df.rename(columns={'description': 'Class Description'}, inplace=True)

peloton_workouts_df.rename(columns={'difficulty_level': 'Level of Difficulty'}, inplace=True)

peloton_workouts_df.rename(columns={'fitness_discipline': 'Type of Exercise'}, inplace=True)

peloton_workouts_df.rename(columns={'is_explicit': 'Music w/ Explicit Lyrics'}, inplace=True)

peloton_workouts_df.rename(columns={'metrics': 'Health Impact'}, inplace=True)

peloton_workouts_df.rename(columns={'duration': 'Class Length'}, inplace=True)

peloton_workouts_df.rename(columns={'workout_type': 'Class Name'}, inplace=True)

# %%
peloton_workouts_df.head (40000)
# Out:
#                                        Class Description Level of Difficulty  \
# 2      Fitness is for everyone! This class is specifi...        intermediate
# 5      In this power flow class, you will flow at a f...        intermediate
# 6      Our upper body classes combine movements that ...        intermediate
# 11     Increase your strength and endurance in this i...        intermediate
# 12     Aditi designed this yoga sequence to help you ...        intermediate
# ...                                                  ...                 ...
# 32520  In this active, vinyasa-style yoga class, well...            beginner
# 32522  Loosen up your glutes and legs after a challen...        intermediate
# 32523  Crank that incline up a few notches to build s...        intermediate
# 32526  Grab your weights and join us for an arm and s...        intermediate
# 32527  In this active, vinyasa-style yoga class, well...        intermediate
#
# ...

# %%
peloton_workouts_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9502 entries, 2 to 32527
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Class Description         9502 non-null   object
#  1   Level of Difficulty       9502 non-null   object
#  2   Type of Exercise          9502 non-null   object
#  3   instructor_id             9502 non-null   object
#  4   Music w/ Explicit Lyrics  9502 non-null   object
#  5   Health Impact             9502 non-null   object
#  6   Class Length              9407 non-null   object
#  7   Class Name                9407 non-null   object
# dtypes: object(8)
# memory usage: 668.1+ KB

# %%
merged_df = peloton_workouts_df.merge(peloton_instructors_df, left_on='instructor_id', right_on='id', how='inner')

# %%
merged_df['Instructor Name'] = merged_df['id'] + ' ' + merged_df['instructor_id']

# %%
merged_df.sort_values(by='Instructor Name', inplace=True)

# %%
merged_df.drop(columns=['id', 'instructor_id'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 merged_df.drop(columns=['id', 'instructor_id'], inplace=True)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
merged_df.rename(columns={'Class Description': 'Class_Description', 'Level of Difficulty': 'Level_of_Difficulty', 'Type of Exercise': 'Type_of_Exercise', 'Music w/ Explicit Lyrics': 'Music_w_Explicit_Lyrics', 'Class Length': 'Class_Length', 'Health Impact': 'Health_Impact', 'Class Name': 'Class_Name'}, inplace=True)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9149 entries, 8144 to 3963
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Class_Description        9149 non-null   object
#  1   Level_of_Difficulty      9149 non-null   object
#  2   Type_of_Exercise         9149 non-null   object
#  3   Music_w_Explicit_Lyrics  9149 non-null   object
#  4   Health_Impact            9149 non-null   object
#  5   Class_Length             9054 non-null   object
#  6   Class_Name               9054 non-null   object
#  7   quote                    9149 non-null   object
#  8   name                     9149 non-null   object
#  9   Instructor Name          9149 non-null   object
# dtypes: object(10)
# memory usage: 786.2+ KB

# %%
merged_df['Health Impact'] = merged_df['Health Impact'].str.replace('[', '', regex=False).str.replace(']', '', regex=False).str.replace("'", '', regex=False).str.replace('_', ' ', regex=True)

# %%
merged_df.head (40000)
# Out:
#                                       Class_Description Level_of_Difficulty  \
# 8144  This yoga class focuses on building skills sur...        intermediate
# 8104  This is a yoga class where the pace is slower ...            beginner
# 8105  Chelsea designed this yoga sequence to help yo...        intermediate
# 8106  Join this yoga basics class focusing on hypere...        intermediate
# 8107  Chelsea designed this yoga sequence to help yo...        intermediate
# ...                                                 ...                 ...
# 3967  Increase your strength and endurance in this i...            beginner
# 3966  High intensity intervals training is an effect...        intermediate
# 3965  Increase your strength and endurance in this i...        intermediate
# 3944  High intensity intervals training is an effect...        intermediate
# 3963  High intensity intervals training is an effect...        intermediate
#
#      Type_of_Exercise Music_w_Explicit_Lyrics  \
# ...

# %%
merged_df.drop(columns=['Instructor Name'], inplace=True)

# %%
merged_df.head (40000)
# Out:
#                                       Class_Description Level_of_Difficulty  \
# 8144  This yoga class focuses on building skills sur...        intermediate
# 8104  This is a yoga class where the pace is slower ...            beginner
# 8105  Chelsea designed this yoga sequence to help yo...        intermediate
# 8106  Join this yoga basics class focusing on hypere...        intermediate
# 8107  Chelsea designed this yoga sequence to help yo...        intermediate
# ...                                                 ...                 ...
# 3967  Increase your strength and endurance in this i...            beginner
# 3966  High intensity intervals training is an effect...        intermediate
# 3965  Increase your strength and endurance in this i...        intermediate
# 3944  High intensity intervals training is an effect...        intermediate
# 3963  High intensity intervals training is an effect...        intermediate
#
#      Type_of_Exercise Music_w_Explicit_Lyrics  \
# ...

# %%
merged_df.rename(columns={'name': 'Instructor Name'}, inplace=True)

# %%
merged_df.head (40000)
# Out:
#                                       Class_Description Level_of_Difficulty  \
# 8144  This yoga class focuses on building skills sur...        intermediate
# 8104  This is a yoga class where the pace is slower ...            beginner
# 8105  Chelsea designed this yoga sequence to help yo...        intermediate
# 8106  Join this yoga basics class focusing on hypere...        intermediate
# 8107  Chelsea designed this yoga sequence to help yo...        intermediate
# ...                                                 ...                 ...
# 3967  Increase your strength and endurance in this i...            beginner
# 3966  High intensity intervals training is an effect...        intermediate
# 3965  Increase your strength and endurance in this i...        intermediate
# 3944  High intensity intervals training is an effect...        intermediate
# 3963  High intensity intervals training is an effect...        intermediate
#
#      Type_of_Exercise Music_w_Explicit_Lyrics  \
# ...

# %%
merged_df.rename(columns={
    'Class_Description': 'Class Description',
    'Level_of_Difficulty': 'Level of Difficulty',
    'Type_of_Exercise': 'Type of Exercise',
    'Music_w_Explicit_Lyrics': 'Music w/ Explicit Lyrics',
    'Health_Impact': 'Health Impact',
    'Class_Length': 'Class Length',
    'Class_Name': 'Class Name',
    'quote': 'Favorite Quote'
}, inplace=True)

# %%
desired_columns = [
    'Instructor Name',
    'Favorite Quote',
    'Type of Exercise',
    'Level of Difficulty',
    'Music w/ Explicit Lyrics',
    'Class Length',
    'Health Impact',
    'Class Name',
    'Class Description'
]

# %%
merged_df = merged_df[desired_columns]

# %%
merged_df.head (40000)
# Out:
#               Instructor Name  \
# 8144  Chelsea Jackson Roberts
# 8104  Chelsea Jackson Roberts
# 8105  Chelsea Jackson Roberts
# 8106  Chelsea Jackson Roberts
# 8107  Chelsea Jackson Roberts
# ...                       ...
# 3967     Joslyn Thompson Rule
# 3966     Joslyn Thompson Rule
# 3965     Joslyn Thompson Rule
# 3944     Joslyn Thompson Rule
# 3963     Joslyn Thompson Rule
#
#                                          Favorite Quote Type of Exercise  \
# 8144  I want to be someone people relate to. I’ll en...             yoga
# 8104  I want to be someone people relate to. I’ll en...             yoga
# 8105  I want to be someone people relate to. I’ll en...             yoga
# 8106  I want to be someone people relate to. I’ll en...             yoga
# 8107  I want to be someone people relate to. I’ll en...             yoga
# ...                                                 ...              ...
# 3967            Let’s just see how far we can take this          running
# ...

# %%
merged_df.head (40000)
# Out:
#               Instructor Name  \
# 8144  Chelsea Jackson Roberts
# 8104  Chelsea Jackson Roberts
# 8105  Chelsea Jackson Roberts
# 8106  Chelsea Jackson Roberts
# 8107  Chelsea Jackson Roberts
# ...                       ...
# 3967     Joslyn Thompson Rule
# 3966     Joslyn Thompson Rule
# 3965     Joslyn Thompson Rule
# 3944     Joslyn Thompson Rule
# 3963     Joslyn Thompson Rule
#
#                                          Favorite Quote Type of Exercise  \
# 8144  I want to be someone people relate to. I’ll en...             yoga
# 8104  I want to be someone people relate to. I’ll en...             yoga
# 8105  I want to be someone people relate to. I’ll en...             yoga
# 8106  I want to be someone people relate to. I’ll en...             yoga
# 8107  I want to be someone people relate to. I’ll en...             yoga
# ...                                                 ...              ...
# 3967            Let’s just see how far we can take this          running
# ...

# %%
csv_file_path = 'Peloton_Data.csv'

# %%
merged_df.to_csv(csv_file_path, index=False)

# %%
print(f"CSV file saved to {csv_file_path}")
# Out:
# CSV file saved to Peloton_Data.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('Peloton_Data.csv')

# %%
unique_health_impact_values = merged_df['Health Impact'].unique()

# %%
for value in unique_health_impact_values:
    print(value)
# Out:
# heart rate, calories
# heart rate
# heart rate, calories, speed, distance, elevation
# heart rate, cadence, calories

# %%
merged_df['Focus'] = merged_df['Health Impact'].str.extract(r'(\d+\s*(?:speed|distance|calories))')[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Health Impact'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
merged_df.head (40000)
# Out:
#               Instructor Name  \
# 8144  Chelsea Jackson Roberts
# 8104  Chelsea Jackson Roberts
# 8105  Chelsea Jackson Roberts
# 8106  Chelsea Jackson Roberts
# 8107  Chelsea Jackson Roberts
# ...                       ...
# 3967     Joslyn Thompson Rule
# 3966     Joslyn Thompson Rule
# 3965     Joslyn Thompson Rule
# 3944     Joslyn Thompson Rule
# 3963     Joslyn Thompson Rule
#
#                                          Favorite Quote Type of Exercise  \
# 8144  I want to be someone people relate to. I’ll en...             yoga
# 8104  I want to be someone people relate to. I’ll en...             yoga
# 8105  I want to be someone people relate to. I’ll en...             yoga
# 8106  I want to be someone people relate to. I’ll en...             yoga
# 8107  I want to be someone people relate to. I’ll en...             yoga
# ...                                                 ...              ...
# 3967            Let’s just see how far we can take this          running
# ...

# %%
import pandas as pd
from pathlib import Path

# Load the original data from workouts.csv into a new DataFrame
original_data = pd.read_csv('workouts.csv', low_memory=False)

# Extract the "metrics" column from the original DataFrame
merged_df['Focus'] = original_data['metrics']

# %%
merged_df.head (40000)
# Out:
#               Instructor Name  \
# 8144  Chelsea Jackson Roberts
# 8104  Chelsea Jackson Roberts
# 8105  Chelsea Jackson Roberts
# 8106  Chelsea Jackson Roberts
# 8107  Chelsea Jackson Roberts
# ...                       ...
# 3967     Joslyn Thompson Rule
# 3966     Joslyn Thompson Rule
# 3965     Joslyn Thompson Rule
# 3944     Joslyn Thompson Rule
# 3963     Joslyn Thompson Rule
#
#                                          Favorite Quote Type of Exercise  \
# 8144  I want to be someone people relate to. I’ll en...             yoga
# 8104  I want to be someone people relate to. I’ll en...             yoga
# 8105  I want to be someone people relate to. I’ll en...             yoga
# 8106  I want to be someone people relate to. I’ll en...             yoga
# 8107  I want to be someone people relate to. I’ll en...             yoga
# ...                                                 ...              ...
# 3967            Let’s just see how far we can take this          running
# ...

# %%
df = pd.read_csv('Project_2.csv')

# %%
df.head (40000)
# Out:
#               Instructor Name  \
# 0     Chelsea Jackson Roberts
# 1     Chelsea Jackson Roberts
# 2     Chelsea Jackson Roberts
# 3     Chelsea Jackson Roberts
# 4     Chelsea Jackson Roberts
# ...                       ...
# 9144     Joslyn Thompson Rule
# 9145     Joslyn Thompson Rule
# 9146     Joslyn Thompson Rule
# 9147     Joslyn Thompson Rule
# 9148     Joslyn Thompson Rule
#
#                                          Favorite Quote Type of Exercise  \
# 0     I want to be someone people relate to. I’ll en...             yoga
# 1     I want to be someone people relate to. I’ll en...             yoga
# 2     I want to be someone people relate to. I’ll en...             yoga
# 3     I want to be someone people relate to. I’ll en...             yoga
# 4     I want to be someone people relate to. I’ll en...             yoga
# ...                                                 ...              ...
# 9144            Let’s just see how far we can take this          running
# ...

# %%
df.head (40000)
# Out:
#               Instructor Name  \
# 0     Chelsea Jackson Roberts
# 1     Chelsea Jackson Roberts
# 2     Chelsea Jackson Roberts
# 3     Chelsea Jackson Roberts
# 4     Chelsea Jackson Roberts
# ...                       ...
# 9144     Joslyn Thompson Rule
# 9145     Joslyn Thompson Rule
# 9146     Joslyn Thompson Rule
# 9147     Joslyn Thompson Rule
# 9148     Joslyn Thompson Rule
#
#                                          Favorite Quote Type of Exercise  \
# 0     I want to be someone people relate to. I’ll en...             yoga
# 1     I want to be someone people relate to. I’ll en...             yoga
# 2     I want to be someone people relate to. I’ll en...             yoga
# 3     I want to be someone people relate to. I’ll en...             yoga
# 4     I want to be someone people relate to. I’ll en...             yoga
# ...                                                 ...              ...
# 9144            Let’s just see how far we can take this          running
# ...

# %%
df = pd.read_csv('Stop.csv')

# %%
df.head (40000)
# Out:
#               Instructor Name  \
# 0     Chelsea Jackson Roberts
# 1     Chelsea Jackson Roberts
# 2     Chelsea Jackson Roberts
# 3     Chelsea Jackson Roberts
# 4     Chelsea Jackson Roberts
# ...                       ...
# 9144     Joslyn Thompson Rule
# 9145     Joslyn Thompson Rule
# 9146     Joslyn Thompson Rule
# 9147     Joslyn Thompson Rule
# 9148     Joslyn Thompson Rule
#
#                                          Favorite Quote Type of Exercise  \
# 0     I want to be someone people relate to. I’ll en...             yoga
# 1     I want to be someone people relate to. I’ll en...             yoga
# 2     I want to be someone people relate to. I’ll en...             yoga
# 3     I want to be someone people relate to. I’ll en...             yoga
# 4     I want to be someone people relate to. I’ll en...             yoga
# ...                                                 ...              ...
# 9144            Let’s just see how far we can take this          running
# ...

# %% [markdown]
# import pandas as pd
# import pymongo

# %%
# !pip install pandas pymongo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#                                               0.0/468.2 kB ? eta -:--:--
#      ---                                   41.0/468.2 kB 653.6 kB/s eta 0:00:01
#      -------------------                    235.5/468.2 kB 2.4 MB/s eta 0:00:01
#      -------------------------------------- 468.2/468.2 kB 3.7 MB/s eta 0:00:00
# ...
#   Using cached dnspython-2.4.2-py3-none-any.whl (300 kB)
# ...

# %%
import pandas as pd

# %%
import pymongo

# %%
import sqlite3

# %%
conn = sqlite3.connect('Peloton_Data.db')

# %%
cursor = conn.cursor()

# %%
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

# %%
create_table_sql = '''
CREATE TABLE IF NOT EXISTS Peloton_Data (
    id INTEGER PRIMARY KEY,
    Instructor_Name Text,
    Favorite_Quote Text,
    Type_of_Exercise Text,
    Level_of_Difficulty Text,
    Music_w_Explicit_Lyrics Text,
    Class_Length Text,
    Focus Text,
    Class_Name Text,
    Class_Description Text
);
'''

# %%
cursor.execute(create_table_sql)

# %%
de = pd.read_csv('Stop.csv')

# %%
de.to_sql('Peloton_Data', conn, if_exists='replace', index=False)
# Out:
# 9149

# %%
conn.commit()

# %%
conn.close()

# %%
conn = sqlite3.connect('Peloton_Data.db')

# %%
cursor = conn.cursor()

# %%
cursor.execute('SELECT * FROM Peloton_Data')
data = cursor.fetchall()

# %%
for row in data:
    print(row)
# Out:
# ('Chelsea Jackson Roberts', 'I want to be someone people relate to. I’ll encourage you as I push you.', 'yoga', 'intermediate', 0, '20 min', 'calories', 'Focus Flow: Floor Poses', 'This yoga class focuses on building skills surrounding a category of related postures. In this class, youll work on floor poses.')
# ('Chelsea Jackson Roberts', 'I want to be someone people relate to. I’ll encourage you as I push you.', 'yoga', 'beginner', 0, '20 min', 'calories', 'Slow Flow', 'This is a yoga class where the pace is slower than our other yoga flow classes. Poses are held for longer durations, which allows for more instruction, and generally a deeper experience of the poses.')
# ('Chelsea Jackson Roberts', 'I want to be someone people relate to. I’ll encourage you as I push you.', 'yoga', 'intermediate', 0, '45 min', 'calories', 'Morning Yoga Flow', 'Chelsea designed this yoga sequence to help you start your day!')
# ...

# %%
conn.close()
